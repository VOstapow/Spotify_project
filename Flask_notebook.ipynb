# %%
import pandas as pd
import matplotlib.pyplot as plt
#from config import username, password
username = 'postgres'
password = ''
# %matplotlib inline

# %%
from sqlalchemy import create_engine
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/spotify_DB')

# %%
connection = engine.connect()

# %%
spotify = pd.read_sql('select * from spotify_data', connection)

# %%
spotify.head()
# Out:
#                                     uri  rank  artist_names  \
# 0  spotify:track:2gpQi3hbcUAcEG8m2dlgfB     1  Paulo Londra
# 1  spotify:track:2x8oBuYaObjqHqgGuIUZ0b     2           WOS
# 2  spotify:track:2SJZdZ5DLtlRosJ2xHJJJa     3  Paulo Londra
# 3  spotify:track:1O2pcBJGej0pmH2Y9XZMs6     5       Cris Mj
# 4  spotify:track:1TpZKxGnHp37ohJRszTSiq     6        Emilia
#
#                                artist_id       artist_genre  \
# 0  spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z  argentine hip hop
# 1  spotify:artist:5YCc6xS5Gpj3EkaYGdjyNK    argentine indie
# 2  spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z  argentine hip hop
# 3  spotify:artist:1Yj5Xey7kTwvZla8sqdsdE     urbano chileno
# 4  spotify:artist:0AqlFI0tz2DsEoJlKSIiT9      pop argentino
#
#                                           artist_img             track_name  \
# 0  https://i.scdn.co/image/ab6761610000e5ebf796a9...                 Plan A
# 1  https://i.scdn.co/image/ab6761610000e5eb75e151...           ARRANCARMELO
# 2  https://i.scdn.co/image/ab6761610000e5ebf796a9...                 Chance
# 3  https://i.scdn.co/image/ab6761610000e5eb8f4ebc...  Una Noche en Medellín
# 4  https://i.scdn.co/image/ab6761610000e5ebaf96d1...          cuatro veinte
#
#                                          album_cover  peak_rank  \
# 0  https://i.scdn.co/image/ab67616d0000b2737e1179...          1
# 1  https://i.scdn.co/image/ab67616d0000b273d8c994...          2
# 2  https://i.scdn.co/image/ab67616d0000b273274a28...          3
# 3  https://i.scdn.co/image/ab67616d0000b273697ed1...          5
# 4  https://i.scdn.co/image/ab67616d0000b273116b57...          6
#
#    weeks_on_chart  streams        week  danceability  loudness  acousticness  \
# 0               4  3003411  2022-04-14         0.583    0.0495        -4.875
# 1               2  2512175  2022-04-14         0.654    0.7240        -7.358
# 2               2  2408983  2022-04-14         0.721    0.2410        -9.483
# 3               8  2080139  2022-04-14         0.870    0.0924        -5.253
# 4               3  1923270  2022-04-14         0.761    0.0811        -3.817
#
#      tempo    country
# 0  173.935  Argentina
# 1   81.956  Argentina
# 2  137.915  Argentina
# 3   96.018  Argentina
# 4   95.066  Argentina
