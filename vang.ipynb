# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# Csv pathway 
songs_path = "../final.csv"

# Read csv file
df = pd.read_csv(songs_path, low_memory=False) 
df.head()
# Out:
#    Unnamed: 0                                   uri rank  artist_names  \
# 0           0  spotify:track:2gpQi3hbcUAcEG8m2dlgfB    1  Paulo Londra
# 1           1  spotify:track:2x8oBuYaObjqHqgGuIUZ0b    2           WOS
# 2           2  spotify:track:2SJZdZ5DLtlRosJ2xHJJJa    3  Paulo Londra
# 3           3  spotify:track:1O2pcBJGej0pmH2Y9XZMs6    5       Cris Mj
# 4           4  spotify:track:1TpZKxGnHp37ohJRszTSiq    6        Emilia
#
#   artists_num artist_individual                              artist_id  \
# 0         1.0      Paulo Londra  spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z
# 1         1.0               WOS  spotify:artist:5YCc6xS5Gpj3EkaYGdjyNK
# 2         1.0      Paulo Londra  spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z
# 3         1.0           Cris Mj  spotify:artist:1Yj5Xey7kTwvZla8sqdsdE
# 4         1.0            Emilia  spotify:artist:0AqlFI0tz2DsEoJlKSIiT9
#
#         artist_genre                                         artist_img  \
# ...

# %%
# Create new DataFrame 
new_df = pd.DataFrame(df[["uri", "rank", "artist_names", "artist_id", "artist_img", "track_name", "album_cover", "peak_rank", "weeks_on_chart", "streams", "week", "country", "danceability", "acousticness", "loudness", "tempo"]])
new_df = new_df.loc[new_df["rank"]!="rank"]
# new_df.set_index("uri", inplace=True)
new_df.head()
# Out:
#                                     uri rank  artist_names  \
# 0  spotify:track:2gpQi3hbcUAcEG8m2dlgfB    1  Paulo Londra
# 1  spotify:track:2x8oBuYaObjqHqgGuIUZ0b    2           WOS
# 2  spotify:track:2SJZdZ5DLtlRosJ2xHJJJa    3  Paulo Londra
# 3  spotify:track:1O2pcBJGej0pmH2Y9XZMs6    5       Cris Mj
# 4  spotify:track:1TpZKxGnHp37ohJRszTSiq    6        Emilia
#
#                                artist_id  \
# 0  spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z
# 1  spotify:artist:5YCc6xS5Gpj3EkaYGdjyNK
# 2  spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z
# 3  spotify:artist:1Yj5Xey7kTwvZla8sqdsdE
# 4  spotify:artist:0AqlFI0tz2DsEoJlKSIiT9
#
#                                           artist_img             track_name  \
# 0  https://i.scdn.co/image/ab6761610000e5ebf796a9...                 Plan A
# 1  https://i.scdn.co/image/ab6761610000e5eb75e151...           ARRANCARMELO
# 2  https://i.scdn.co/image/ab6761610000e5ebf796a9...                 Chance
# ...

# %%
new_df.dtypes
# Out:
# uri               object
# rank              object
# artist_names      object
# artist_id         object
# artist_img        object
# track_name        object
# album_cover       object
# peak_rank         object
# weeks_on_chart    object
# streams           object
# week              object
# country           object
# danceability      object
# acousticness      object
# loudness          object
# tempo             object
# dtype: object

# %%
# Convert datatypes
types ={"rank": int, 
        "peak_rank": int,
        "weeks_on_chart": int, 
        "streams": int, 
        "week": "datetime64", 
        "danceability": float, 
        "acousticness": float, 
        "loudness": float, 
        "tempo": float 
        }
new_df = new_df.astype(types)
new_df.dtypes
# Out:
# uri                       object
# rank                       int32
# artist_names              object
# artist_id                 object
# artist_img                object
# track_name                object
# album_cover               object
# peak_rank                  int32
# weeks_on_chart             int32
# streams                    int32
# week              datetime64[ns]
# country                   object
# danceability             float64
# acousticness             float64
# loudness                 float64
# tempo                    float64
# dtype: object

# %%
# Save to csv 
# new_df.to_csv("vang2.csv", index=False)
